# %%
# !rm -rf ./CCDM-DR

# %%
# !git clone https://github.com/Lamine-MOH/CCDM-DR

# %%
# !python CCDM-DR/data_preparation/get_dataset.py --dataset IDRiD

# %%
# !python CCDM-DR/data_preparation/build_dr_h5.py \
      --image_dir ./data/IDRiD/Images \
      --csv_path  ./data/IDRiD/labels.csv \
      --out_dir   ./data/DRGrading \
      --img_size  256
